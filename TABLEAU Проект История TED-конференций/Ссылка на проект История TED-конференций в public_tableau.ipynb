# %% [markdown]
# <div class="alert alert-success">
# <b> Комментарий от ревьюера 2</b>
#
# Спасибо, что учла мои комментарии. Ты приложила много усилий, чтобы довести проект до конца, надеюсь, что эта работа помогла тебе лучше понять теорию. Я принимаю проект и желаю удачи в прохождении курса!
#
# Для изучения дополнительной информации по Tableau могу посоветовать [этот марафон](https://tableau.pro/m00). В нем есть много полезных советов, ссылок на книги и дополнительные ресурсы.
#
# [Плейлист с решением задач марафона](https://www.youtube.com/playlist?list=PLgG9iJlSBmTcMvZqpKTPDrNC_zq1xKOxQ).
#
# </div>

# %% [markdown]
# Добрый день! Ссылка:

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Добрый день, Елена.
#
# Меня зовут Людмила, и я буду проводить ревью твоего проекта.
#
# Предлагаю перейти на «ты», если не против)
#
# Но если это не удобно — дай знать, и мы перейдем на «вы». Моя главная задача — не находить сделанные тобою ошибки, а передать свой опыт и помочь тебе стать аналитиком данных.
#
# Мои комментарии будут в ячейках «Комментарий ревьюера».
#
# ---
# <div class="alert alert-block alert-danger">
#
# Критическое замечание, которые следует исправить.
# </div>
#
# <div class="alert alert-block alert-warning">
#
# Замечание\совет на будущее.
# </div>
#
# <div class="alert alert-block alert-success">
#
# Когда всё сделано правильно.
# </div>
#
# ---
#
# Укажи, пожалуйста, изменения в проект, которые ты внесешь, в своем комментарии. Будет удобно, если ты поместишь его
#
# <div class="alert alert-info">
#
# в такую ячейку
# </div>
#
# Давай при работе с проектом мы будем общаться с тобой в диалоге, поэтому не удаляй мои комментарии, это поможет мне сделать повторную  проверку проекта быстрее.
# ___

# %% [markdown]
# https://public.tableau.com/app/profile/elena.ukraina/viz/TED-_17152046748950/TED-

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Комментарий ревьюера:</b>
#
# **История выступлений**
#
# * Ты использовала правильные способы для объединения таблиц.
# * На дашборде представлены все нужные визуализации.
# * Ты выделяешь топ тематик выступлений, и графики получаются не перегруженными информацией.
# * Здорово, что ты подписываешь секторы графиков, так они становятся нагляднее.
# * Настроен Action для фильтрации графиков.
# * Хорошо, что ты меняешь автоматически сформированные наименования во всплывающих подсказках.
# * Есть выводы с ответами на вопросы задания.
#
# **Тематики выступлений**
#
# * На круговой диаграмме показано топ-10 тем, остальные объединены в категорию "другие", настроена всплывающая подсказка с гистограммами длительности и просмотров.
# * Ты правильно выделяешь топ-3 страны.
# * Корректно созданы новые вычисляемые поля и графики на их основе, диаграммы размаха отсортированы по медиане.
# * Хорошо, что тематики на круговой диаграмме и диаграммах размаха выделены одинаковыми цветами.
# * Хорошо, что на график связи длительности с просмотрами добавлены линии тренда.
#
# **Авторы выступлений**
#
# * Правильно настроена визуализация "Области деятельности авторов".
# * Таблицы "Авторы по числу выступлений" и "Выступления и число просмотров" отсортированы по убыванию.
# * Настроены оба Action.
# * Хорошо, что в столбцах графика подписаны значения. Благодаря этому необязательно пользоваться всплывающей подсказкой.
#
# **Свободная тема**
#
# * Ты выбрала интересную тему для дополнительного дашборда, здорово, что на дашборде настроен Action.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Комментарий ревьюера:</b>
#
# **История выступлений**
#
# * В проекте данные отфильтрованы с 2007 г., но рост числа выступлений начинается уже с 2001 г., поэтому границу стоит сдвинуть.
# * Здесь и на следующих листах презентации можно убрать цветовые легенды, так как все нужные пояснения уже есть на графиках.
# * В выводы можно добавить предположение, с чем связано изменение состава выступлений в 20-21 гг.
#
# **Авторы выступлений**
#
# * Можно немного увеличить слайдер для выбора количества топ-областей деятельности, чтобы им было удобнее пользоваться.
#
# **Свободная тема**
#
# * Круги на карте можно заменить на выделение страны, как на первом дашборде. Можно добавить также разбивку по цвету.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Комментарий ревьюера:</b>
#
# **История выступлений**
#
# * Для графика с выступлениями по годам установлено ограничение оси X. Его лучше убрать:
#
# ![image.png](attachment:image.png)
#
# **Тематики выступлений**
#
# * В таблице "Тематики и страны" разбивка по цвету должна совпадать с заполнением текстом (чем больше число, тем более темным цветом оно должно быть выделено).
#
# **Авторы выступлений**
#
# * Talks by author (bin) для графика "Распределение числа выступлений" надо поменять на Talks by author в формате Discrete. Тогда столбцы будут отделены друг от друга.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Итоговый комментарий ревьюера:</b>
#
# Благодарю тебя за выполнение проекта. Вижу ты постаралась, когда работала над ним. У тебя получилась логичная презентация, и ты ответила на все вопросы задания. Однако, в проекте есть несколько замечаний, которые надо исправить:
#
# * дополнить оформление графиков;
# * скорректировать график "Распределение числа выступлений".
#
# Жду проект после доработки. Уверена, ты справишься. 💪
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Людмила, добрый день, внесла исправления:
#
# **История выступлений**
#
# * Убрала ограничение по оси Х в графике "Выступления по годам"
# * Убрала цветовые легенды здесь и на следующих листах презентации.
# * Добавила в выводы предположение, с чем связано изменение состава выступлений в 20-21 гг.
#
# **Тематики выступлений**
#
# * Людмила, подскажи как исправить замечание: **В таблице "Тематики и страны" разбивка по цвету должна совпадать с заполнением текстом (чем больше число, тем более темным цветом оно должно быть выделено).**
#
# Как я понимаю, выделение цветом в тепловой карте есть, чем больше значение процента, тем темнее цвет ячейки
#
# ![image.png](attachment:image.png)
#
# **Авторы выступлений**
#
# * Исправила формат Talks by author (bin) на Discrete в графике "Распределение числа выступлений" и
# * Увеличила слайдер для выбора количества топ-областей деятельности.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Комментарий ревьюера 2:</b>
#
# На твоём скриншоте самым темным цветом выделено число 19.39%. Но в проекте разбивка по цвету исправлена, и самым темным цветом выделено число 24%:
#
# ![image.png](attachment:image.png)
#
# </div>
